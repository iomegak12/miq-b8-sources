# %% [markdown]
# ### LangChain - Summary Chain - Out-of-the-Box

# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain.chains.summarize import load_summarize_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
load_dotenv()

openai_api_key = os.environ["OPENAI_API_KEY"]
model_name = "gpt-3.5-turbo"
temperature = 0.1
max_tokens = 1000

llm = ChatOpenAI(
    model = model_name,
    temperature=temperature,
    max_tokens=max_tokens,
    openai_api_key = openai_api_key
)

# %%
with open("../lc-training-data/good.txt", "r") as file:
    text = file.read()
    
print(text[:100])
# Out:
# Be Good
#
# April 2008
#
# (This essay is derived from a talk at the 2008 Startup School.)
#
# About a month

# %%
number_of_tokens = llm.get_num_tokens(text)

print(f"There are {number_of_tokens} Token(s) in the file!")
# Out:
# There are 3581 Token(s) in the file!

# %%
text_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n"],
    chunk_size = 3000,
    chunk_overlap = 300
)

# %%
documents = text_splitter.create_documents([text])

print(f"Now, you have {len(documents)} documents instead of 1 document!")
# Out:
# Now, you have 6 documents instead of 1 document!

# %%
chain = load_summarize_chain(
    llm = llm,
    chain_type = "map_reduce"
)

# %%
output = chain.invoke(documents)

# %%
print(output["output_text"])
# Out:
# The essay emphasizes the importance of creating something people want and prioritizing benevolence over profit in startups. It discusses successful examples like Craigslist and Google, as well as the potential benefits of running a business like a charity. The author highlights the power of benevolence in driving successful ventures, using Microsoft as an example of a company that lost its way by mistreating customers. The challenges faced by startups, the importance of launching quickly, having a sense of mission, and doing good for users are also discussed. The story of Octopart illustrates the struggle between good and evil in business practices, emphasizing the benefits of being committed, resilient, and attracting help from others. The author acknowledges the importance of being good in business, not out of sanctimoniousness, but because it is effective in various aspects of life.
